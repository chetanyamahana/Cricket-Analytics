# %%
import numpy as np
import pandas as pd

# %%
batsman_df=pd.read_excel('6655876402143_batsman_round1 (1).xlsx')
bowler_df=pd.read_excel('6655876ef0ec2_bowler_round1.xlsx')
matches_df=pd.read_excel('6655877834f04_matchlevel_round1.xlsx')

# %%
batsman_df.head()
# Out:
#    match id batsman  batsman_id batsman_dob  \
# 0   8638034   DG Be       31464  1984-07-30
# 1   8638041   DG Be       31464  1984-07-30
# 2   8638055   DG Be       31464  1984-07-30
# 3   8587802   DT Cn       34061  1983-05-04
# 4   8587802   DT Cn       34061  1983-05-04
#
#                              batsman_details  is_batsman_captain  \
# 0        NZ:Right-hand bat:Right-arm medium:                   0
# 1        NZ:Right-hand bat:Right-arm medium:                   0
# 2        NZ:Right-hand bat:Right-arm medium:                   0
# 3  AUS:Right-hand bat:Right-arm fast-medium:                   0
# 4  AUS:Right-hand bat:Right-arm fast-medium:                   0
#
#    is_batsman_keeper  inning  runs  balls_faced  ...  bowler_id  bowler_dob  \
# 0                  0       1   8.0           11  ...  2486896.0  1990-09-17
# 1                  0       1   2.0            4  ...  4195827.0  1993-04-13
# 2                  0       2   0.0            3  ...  8447396.0  1994-12-14
# 3                  0       2   0.0            1  ...  6722540.0  2000-08-02
# 4                  0       2   0.0            1  ...  6722540.0  2000-08-02
#
#                              bowler_details is_bowler_keeper  \
# 0   NZ:Left-hand bat:Right-arm medium-fast:              0.0
# 1       NZ:Right-hand bat:Right-arm medium:              0.0
# 2  NZ:Left-hand bat:Slow left-arm orthodox:              0.0
# 3       NEP:Right-hand bat:Legbreak googly:              0.0
# 4       NEP:Right-hand bat:Legbreak googly:              0.0
#
#    is_bowler_captain strike_rate Fours  Sixes    match_dt  ingestion_timestamp
# 0                0.0       72.73     1    NaN  2021-01-01  2022-03-22 12:43:21
# 1                0.0       50.00   NaN    NaN  2021-01-02  2022-03-22 12:43:21
# 2                0.0        0.00   NaN    NaN  2021-01-04  2022-03-22 12:43:21
# 3                0.0        0.00   NaN    NaN  2021-01-24  2022-03-22 12:43:21
# 4                0.0        0.00   NaN    NaN  2021-01-24  2022-03-13 18:43:20
#
# [5 rows x 24 columns]

# %%
bowler_df.head()
# Out:
#    match id bowler  bowler_id  bowler_dob  \
# 0   8587837  DT Cn      34061  1983-05-04
# 1   8587907  DT Cn      34061  1983-05-04
# 2   8587816  DT Cn      34061  1983-05-04
# 3   8587998  DT Cn      34061  1983-05-04
# 4   8588040  DT Cn      34061  1983-05-04
#
#                               bowler_details  is_bowler_captain  \
# 0  AUS:Right-hand bat:Right-arm fast-medium:                  0
# 1  AUS:Right-hand bat:Right-arm fast-medium:                  0
# 2  AUS:Right-hand bat:Right-arm fast-medium:                  0
# 3  AUS:Right-hand bat:Right-arm fast-medium:                  0
# 4  AUS:Right-hand bat:Right-arm fast-medium:                  0
#
#    is_bowler_keeper  inning  runs  wicket_count  balls_bowled  economy  \
# 0                 0       2  35.0             2            18    11.67
# 1                 0       1  22.0             1            24     5.50
# 2                 0       1  34.0             0            25     8.16
# 3                 0       1  34.0             1            18    11.33
# 4                 0       1  20.0             0            12    10.00
#
#    maiden  dots  Fours  Sixes  wides  noballs    match_dt ingestion_timestamp
# 0       0   4.0      3      1    2.0        0  2021-01-02 2022-03-21 03:44:58
# 1       0   7.0      0      0    1.0        0  2021-01-03 2022-03-21 03:44:58
# 2       0   7.0      4      0    1.0        0  2021-01-06 2022-03-21 03:44:58
# 3       0   8.0      4      2    1.0        0  2021-01-10 2022-03-21 03:44:58
# 4       0   4.0      1      1    1.0        0  2021-01-13 2022-03-21 03:44:58

# %%
matches_df.head()
# Out:
#    match id  team1  team2 outcome winner       by  win amount player of match  \
# 0   8587795  Ae Ss  Me Rs  normal  Me Rs  wickets           6           Md Ni
# 1   8587802  Ht Hs  Sy Ss  normal  Ht Hs     runs           7           MS We
# 2   8587816  Ph Ss  Sy Ss  normal  Ph Ss      NaN          86           MR Mh
# 3   8587837  Sy Ss  Be Ht  normal  Be Ht  wickets           4           MT Se
# 4   8587844  Ae Ss  Me Rs  normal  Ae Ss     runs          60           RJ Gn
#
#   toss winner toss decision  ... inning2_runs inning2_wickets inning2_balls  \
# 0       Ae Ss           bat  ...          178             4.0           120
# 1       Sy Ss         field  ...          181             8.0           120
# 2       Sy Ss         field  ...           97            10.0           100
# 3       Sy Ss           bat  ...          171             6.0           119
# 4       Ae Ss           bat  ...          111            10.0           116
#
#   team1_id                                 team1_roster_names  \
# 0  33914.0  MT Rw:PD St:AT Cy:J Wd:RJ Gn:JW Ws:Rd Kn:DR Bs...
# 1  33928.0  MS We:DM St:BR Mt:DJ Mn:WG Js:TH Dd:NT Es:NP W...
# 2  33935.0  JJ Ry:LS Le:C Mo:JP Is:MR Mh:AJ Tr:AM He:JA Rn...
# 3  33956.0  JR Pe:J Es:JM Ve:DP Hs:JC Sk:DT Cn:CR Be:BJ Ds...
# 4  33914.0  MT Rw:PD St:AT Cy:JW Ws:RJ Gn:J Wd:Rd Kn:DR Bs...
#
#                                     team1_roster_ids team2_id  \
# 0  5056134.0:4685568.0:2285051.0:5469008.0:577649...  33942.0
# 1  1611364.0:2161599.0:4223883.0:1655436.0:628285...  33956.0
# 2  2089079.0:2827327.0:1626526.0:4635658.0:190716...  33956.0
# 3  7869987.0:7620283.0:2076192.0:4002340.0:306369...  33921.0
# 4  5056134.0:4685568.0:2285051.0:1635773.0:577649...  33942.0
#
#                                   team2_roster_names  \
# 0  MW Hy:AJ Fh:SB Hr:Md Ni:JA Pe:J Fk:BJ Wr:Id Wm...
# 1  JR Pe:JM Ve:DP Hs:MC Hs:JC Sk:DT Cn:CR Be:SA A...
# 2  JR Pe:J Es:JM Ve:DP Hs:JC Sk:DT Cn:CR Be:SJ Oe...
# 3  M Bt:JA Bs:JL Dy:SD Ht:JJ Pn:L Gy:JJ By:JD Wh:...
# 4  AJ Fh:MW Hy:SB Hr:Md Ni:BJ Wr:Id Wm:J Fk:JA Pe...
#
#                                     team2_roster_ids ingestion_timestamp
# 0  7534687.0:37351.0:5406540.0:181404.0:6842170.0... 2022-02-18 03:12:45
# 1  7869987.0:2076192.0:4002340.0:41740.0:3063696.... 2022-02-18 03:12:45
# 2  7869987.0:7620283.0:2076192.0:4002340.0:306369... 2022-02-18 03:12:45
# 3  7620269.0:2286437.0:87191.0:5786766.0:3114803.... 2022-02-18 03:12:45
# 4  37351.0:7534687.0:5406540.0:181404.0:2669316.0... 2022-02-18 03:12:45
#
# [5 rows x 33 columns]

# %%
# Function to remove duplicates
def remove_duplicates(df):
    return df.drop_duplicates(keep='last')

# Apply the function to each dataframe
matches_df = remove_duplicates(matches_df)
batsman_df = remove_duplicates(batsman_df)
bowler_df = remove_duplicates(bowler_df)

# Check if duplicates are removed
print(matches_df.duplicated().sum())
print(batsman_df.duplicated().sum())
print(bowler_df.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
matches_df = matches_df[(matches_df['match id'] >= 8000000) & (matches_df['match id'] <= 10000000)]
batsman_df = batsman_df[(batsman_df['match id'] >= 8000000) & (batsman_df['match id'] <= 10000000)]
bowler_df = bowler_df[(bowler_df['match id'] >= 8000000) & (bowler_df['match id'] <= 10000000)]

# %%
batsman_df = batsman_df[(batsman_df['batsman_id'] >= 36000) & (batsman_df['batsman_id'] <= 10000000)]

# %%
for index, row in batsman_df.iterrows():
    if pd.isnull(row['strike_rate']) and not pd.isnull(row['runs']) and not pd.isnull(row['balls_faced']) and row['balls_faced'] != 0:
        batsman_df.at[index, 'strike_rate'] = (row['runs'] / row['balls_faced']) * 100

# %%
batsman_df.head()
# Out:
#     match id batsman  batsman_id batsman_dob  \
# 56   8587865   CJ Fn       36665  1984-11-21
# 57   8587893   CJ Fn       36665  1984-11-21
# 58   8587942   CJ Fn       36665  1984-11-21
# 59   8587970   CJ Fn       36665  1984-11-21
# 60   8588005   CJ Fn       36665  1984-11-21
#
#                          batsman_details  is_batsman_captain  \
# 56  AUS:Right-hand bat:Right-arm medium:                   1
# 57  AUS:Right-hand bat:Right-arm medium:                   1
# 58  AUS:Right-hand bat:Right-arm medium:                   1
# 59  AUS:Right-hand bat:Right-arm medium:                   1
# 60  AUS:Right-hand bat:Right-arm medium:                   1
#
#     is_batsman_keeper  inning  runs  balls_faced  ...  bowler_id  bowler_dob  \
# 56                  0       2  46.0           33  ...        NaN         NaN
# 57                  0       1  23.0           24  ...  5788418.0  1994-09-22
# 58                  0       2  22.0           18  ...  2633196.0  1990-03-29
# 59                  0       1  35.0           34  ...  6818776.0  2001-03-28
# 60                  0       2  11.0            9  ...  1594319.0  1988-12-18
#
#                                bowler_details is_bowler_keeper  \
# 56                                        NaN              NaN
# 57  AUS:Right-hand bat:Right-arm fast-medium:              0.0
# 58  AUS:Right-hand bat:Right-arm medium-fast:              0.0
# 59     AFG:Right-hand bat:Right-arm offbreak:              0.0
# 60  PAK:Left-hand bat:Slow left-arm orthodox:              0.0
#
#     is_bowler_captain strike_rate Fours  Sixes    match_dt  \
# 56                NaN      139.39     6    NaN  2021-01-25
# 57                0.0       95.83     1    NaN  2021-01-18
# 58                0.0      122.22     2    NaN  2021-01-24
# 59                0.0      102.94     4    NaN  2021-01-04
# 60                0.0      122.22     1    NaN  2021-01-01
#
#     ingestion_timestamp
# 56  2022-03-22 12:43:21
# 57  2022-03-22 12:43:21
# 58  2022-03-22 12:43:21
# 59  2022-03-22 12:43:21
# 60  2022-03-22 12:43:21
#
# [5 rows x 24 columns]

# %%
batsman_df.isnull().sum()
# Out:
# match id                   0
# batsman                    0
# batsman_id                 0
# batsman_dob                0
# batsman_details            0
# is_batsman_captain         0
# is_batsman_keeper          0
# inning                     0
# runs                      50
# balls_faced                0
# over_faced_first           0
# wicket kind             5452
# out_by_bowler           5452
# out_by_fielder             6
# bowler_id               6499
# bowler_dob              6499
# bowler_details          6499
# is_bowler_keeper        5912
# is_bowler_captain       6499
# strike_rate                7
# Fours                  10455
# Sixes                  15679
# match_dt                   0
# ingestion_timestamp        0
# dtype: int64

# %%
batsman_df['Fours'].fillna(0, inplace=True)
batsman_df['Sixes'].fillna(0, inplace=True)

# %%
print(batsman_df.isnull().sum())
# Out:
# match id                  0
# batsman                   0
# batsman_id                0
# batsman_dob               0
# batsman_details           0
# is_batsman_captain        0
# is_batsman_keeper         0
# inning                    0
# runs                     50
# balls_faced               0
# over_faced_first          0
# wicket kind            5452
# out_by_bowler          5452
# out_by_fielder            6
# bowler_id              6499
# bowler_dob             6499
# bowler_details         6499
# is_bowler_keeper       5912
# is_bowler_captain      6499
# strike_rate               7
# Fours                     0
# Sixes                     0
# match_dt                  0
# ingestion_timestamp       0
# dtype: int64

# %%
merged_df = pd.merge(
    batsman_df, bowler_df,
    on=['match id', 'bowler_id'],
    how='left',
    suffixes=('', '_y')
)

# %%
merged_df
# Out:
#        match id batsman  batsman_id batsman_dob  \
# 0       8587865   CJ Fn       36665  1984-11-21
# 1       8587893   CJ Fn       36665  1984-11-21
# 2       8587942   CJ Fn       36665  1984-11-21
# 3       8587970   CJ Fn       36665  1984-11-21
# 4       8588005   CJ Fn       36665  1984-11-21
# ...         ...     ...         ...         ...
# 24903   9684982   Sv Dy     9822322  2003-12-23
# 24904   9684541   PR Vr     9822392  2005-11-24
# 24905   9866331   BJ Js     9874052  2002-05-06
# 24906   9887856    T Si     9883250  2005-06-04
# 24907   9887856    S Ua     9899140  1997-02-22
#
#                                   batsman_details  is_batsman_captain  \
# 0            AUS:Right-hand bat:Right-arm medium:                   1
# 1            AUS:Right-hand bat:Right-arm medium:                   1
# 2            AUS:Right-hand bat:Right-arm medium:                   1
# 3            AUS:Right-hand bat:Right-arm medium:                   1
# 4            AUS:Right-hand bat:Right-arm medium:                   1
# ...                                           ...                 ...
# 24903        IND:Right-hand bat:Right-arm medium:                   0
# 24904  IND:Right-hand bat:Slow left-arm orthodox:                   0
# 24905         NZ:Right-hand bat:Right-arm medium:                   0
# 24906                    UAE:Right-hand bat:None:                   0
# 24907                 UAE:Left-hand bat:Legbreak:                   0
#
#        is_batsman_keeper  inning  runs  balls_faced  ...  balls_bowled  \
# 0                      0       2  46.0           33  ...           NaN
# 1                      0       1  23.0           24  ...          24.0
# 2                      0       2  22.0           18  ...          18.0
# 3                      0       1  35.0           34  ...          24.0
# 4                      0       2  11.0            9  ...          18.0
# ...                  ...     ...   ...          ...  ...           ...
# 24903                  0       1   0.0            1  ...           NaN
# 24904                  0       1   0.0            1  ...          24.0
# 24905                  0       2  42.0           20  ...          23.0
# 24906                  1       2  20.0           25  ...           NaN
# 24907                  0       2   4.0           10  ...          24.0
#
#       economy maiden  dots  Fours_y Sixes_y wides  noballs  match_dt_y  \
# 0         NaN    NaN   NaN      NaN     NaN   NaN      NaN         NaN
# 1        8.75    0.0   9.0      3.0     1.0   4.0      0.0  2021-01-18
# 2        5.67    0.0  10.0      2.0     0.0   1.0      0.0  2021-01-24
# 3        6.50    0.0  13.0      0.0     2.0   1.0      0.0  2021-01-04
# 4       11.33    0.0   4.0      6.0     0.0   1.0      0.0  2021-01-01
# ...       ...    ...   ...      ...     ...   ...      ...         ...
# 24903     NaN    NaN   NaN      NaN     NaN   NaN      NaN         NaN
# 24904   14.25    0.0   6.0      5.0     4.0   0.0      1.0  2023-10-21
# 24905    6.78    0.0   9.0      2.0     1.0   0.0      0.0  2023-12-19
# 24906     NaN    NaN   NaN      NaN     NaN   NaN      NaN         NaN
# 24907    4.75    0.0  15.0      2.0     0.0   2.0      0.0  2023-12-29
#
#         ingestion_timestamp_y
# 0                         NaT
# 1     2022-03-21 03:44:58.000
# 2     2022-03-21 03:44:58.000
# 3     2022-03-21 03:44:58.000
# 4     2022-03-21 03:44:58.000
# ...                       ...
# 24903                     NaT
# 24904 2024-03-14 17:12:36.995
# 24905 2024-03-14 17:12:36.995
# 24906                     NaT
# 24907 2024-03-14 17:12:36.995
#
# [24908 rows x 42 columns]

# %%
columns_to_impute = [
    'wicket kind', 'out_by_bowler', 'out_by_fielder', 
    'bowler_id', 'bowler_dob', 'bowler_details', 
    'is_bowler_keeper', 'is_bowler_captain'
]

for column in columns_to_impute:
    if column in merged_df.columns:
        batsman_df[column].fillna(merged_df[f'{column}'], inplace=True)

# %%
batsman_df.isnull().sum()
# Out:
# match id                  0
# batsman                   0
# batsman_id                0
# batsman_dob               0
# batsman_details           0
# is_batsman_captain        0
# is_batsman_keeper         0
# inning                    0
# runs                     50
# balls_faced               0
# over_faced_first          0
# wicket kind            1245
# out_by_bowler          1245
# out_by_fielder            0
# bowler_id              1790
# bowler_dob             1790
# bowler_details         1790
# is_bowler_keeper       1473
# is_bowler_captain      1790
# strike_rate               7
# Fours                     0
# Sixes                     0
# match_dt                  0
# ingestion_timestamp       0
# dtype: int64

# %%
null_run_records = batsman_df[batsman_df['runs'].isnull()]

# Display the records
print(null_run_records)
# Out:
#        match id   batsman  batsman_id batsman_dob  \
# 2933                   0       1   NaN            3  ...  4420828.0
# 3746                   0       2   NaN            2  ...  7353828.0
# 4888                   0       1   NaN           17  ...  9455557.0
# 5592                   0       2   NaN            7  ...  2659502.0
# 6033                   0       1   NaN           15  ...    65183.0
# 6846                   0       1   NaN            2  ...        NaN
# 7068                   0       1   NaN           11  ...  4132295.0
# 7653                   0       2   NaN            2  ...        NaN
# 7829                   0       2   NaN           29  ...  6460614.0
# 8977                   0       2   NaN            1  ...  8106629.0
# 9437                   0       1   NaN            6  ...        NaN
# 9488                   1       2   NaN           53  ...  2733380.0
# 9799                   1       2   NaN           40  ...  1711492.0
# 9891                   0       1   NaN            5  ...  2270519.0
# 9960                   0       1   NaN           21  ...  1642738.0
# 10662                  0       1   NaN           13  ...  3673914.0
# 10786                  0       2   NaN           31  ...  3061225.0
# 10864                  1       2   NaN           43  ...  8055417.0
# 10879                  1       1   NaN           10  ...  3030733.0
# 12691                  0       1   NaN            5  ...   392888.0
# 12909                  0       1   NaN           30  ...  6493346.0
# 13966                  0       1   NaN            6  ...  2097017.0
# 13972                  0       2   NaN            8  ...  4239794.0
# 14296                  0       2   NaN           41  ...   393014.0
# 14631                  0       1   NaN           31  ...  2157770.0
# 14906                  1       1   NaN           23  ...  8067002.0
# 15108                  0       2   NaN            4  ...  3252395.0
# 15187                  0       2   NaN            1  ...  5509524.0
# 15591                  1       1   NaN           44  ...  4393402.0
# 16713                  0       1   NaN           16  ...  8228100.0
# 16745                  0       2   NaN           23  ...  8131255.0
# 19267                  0       2   NaN            3  ...  8228100.0
# 20162                  0       1   NaN           30  ...  1636627.0
# 21214                  0       1   NaN            2  ...  2659222.0
# 22194                  0       2   NaN           23  ...  8059379.0
# 22359                  0       2   NaN           24  ...  3546297.0
# 22883                  0       1   NaN            7  ...  5831622.0
# 23111                  0       1   NaN           62  ...  8713270.0
# 23322                  0       1   NaN           10  ...        NaN
# 23501                  0       1   NaN           30  ...  2236086.0
# 23604                  0       2   NaN           13  ...  6586824.0
# 23983                  0       1   NaN            2  ...  4949790.0
# 24398                  0       2   NaN           17  ...  6930286.0
# 24790                  1       2   NaN            3  ...  1626561.0
#
#        bowler_dob                             bowler_details is_bowler_keeper  \
# 77     1992-10-31                NZ:Right-hand bat:Legbreak:              0.0
# 192    1995-04-08  AUS:Right-hand bat:Right-arm fast-medium:              0.0
# 385    1996-10-09   ENG:Left-hand bat:Right-arm medium-fast:              0.0
# 1897   2003-01-09   SL:Left-hand bat:Slow left-arm orthodox:              0.0
# 2802   1994-12-12     BAN:Right-hand bat:Right-arm offbreak:              0.0
# 2890   2000-03-24  AFG:Right-hand bat:Right-arm medium-fast:              0.0
# 2933   1996-05-26     ENG:Right-hand bat:Right-arm offbreak:              0.0
# 3746   1998-12-17  AUS:Right-hand bat:Right-arm fast-medium:              0.0
# 4888   2003-05-15        IND:Right-hand bat:Legbreak googly:              0.0
# 5592   1990-06-08     SA:Left-hand bat:Left-arm fast-medium:              0.0
# 7653  2023-03-10 21:21:02.995
# 7829  2022-03-22 12:43:21.000
# 8977  2024-03-26 03:41:36.000
# 9437  2022-03-22 12:43:21.000
# 9488  2022-03-22 12:43:21.000
# 9799  2022-03-22 12:43:21.000
# 9891  2023-03-10 21:21:02.995
# 9960  2022-03-22 12:43:21.000
# 10662 2024-03-26 03:41:36.000
# 10786 2024-03-26 03:41:36.000
# 10864 2023-03-10 21:21:02.995
# 10879 2024-03-26 03:41:36.000
# 12691 2023-03-10 21:21:02.995
# 12909 2023-03-10 21:21:02.995
# 13966 2024-03-26 03:41:36.000
# 13972 2023-03-10 21:21:02.995
# 14296 2022-03-22 12:43:21.000
# 14631 2023-03-10 21:21:02.995
# 14906 2024-03-26 03:41:36.000
# 15108 2022-03-22 12:43:21.000
# 15187 2023-03-10 21:21:02.995
# 15591 2024-03-26 03:41:36.000
# 16713 2024-03-26 03:41:36.000
# 16745 2023-03-10 21:21:02.995
# 19267 2023-03-10 21:21:02.995
# 20162 2022-03-22 12:43:21.000
# 21214 2024-03-26 03:41:36.000
# 22194 2024-03-26 03:41:36.000
# 22359 2024-03-26 03:41:36.000
# 22883 2023-03-10 21:21:02.995
# 23111 2024-03-26 03:41:36.000
# 23322 2022-03-22 12:43:21.000
# 23501 2022-03-22 12:43:21.000
# 23604 2024-03-26 03:41:36.000
# 23983 2022-03-22 12:43:21.000
# 24398 2023-03-10 21:21:02.995
# 24790 2024-03-26 03:41:36.000
#
# [50 rows x 24 columns]

# %%
mask = batsman_df['runs'].isnull() & batsman_df['strike_rate'].notnull() & batsman_df['balls_faced'].notnull()

# Calculate runs
batsman_df.loc[mask, 'runs'] = (batsman_df.loc[mask, 'strike_rate'] / 100) * batsman_df.loc[mask, 'balls_faced']

# Optionally round the runs to the nearest integer if required
batsman_df['runs'] = batsman_df['runs'].round().astype('Int64')

# %%
batsman_df.isnull().sum()
# Out:
# match id                  0
# batsman                   0
# batsman_id                0
# batsman_dob               0
# batsman_details           0
# is_batsman_captain        0
# is_batsman_keeper         0
# inning                    0
# runs                      0
# balls_faced               0
# over_faced_first          0
# wicket kind            1245
# out_by_bowler          1245
# out_by_fielder            0
# bowler_id              1790
# bowler_dob             1790
# bowler_details         1790
# is_bowler_keeper       1473
# is_bowler_captain      1790
# strike_rate               7
# Fours                     0
# Sixes                     0
# match_dt                  0
# ingestion_timestamp       0
# dtype: int64

# %%
null_strike_rate_records = batsman_df[batsman_df['strike_rate'].isnull()]

# Display the records
print(null_strike_rate_records)
# Out:
#        match id batsman  batsman_id batsman_dob  \
# 1468    8729230   Wb Rz      305143  1985-06-28
# 4603    9516625   TA Bt     1945397  1989-07-22
# 7783    9256561   JS Nm     2486896  1990-09-17
# 12607   9344453   OG Bn     3747484  1993-03-18
# 20730   9084655   HH Bs     7184666  1999-08-21
# 23028   9084830   TW Hy     8055417  1999-05-03
# 23178   9271807    V Vh     8072056  2001-12-05
#
#                                  batsman_details  is_batsman_captain  \
# 1468           PAK:Right-hand bat:Left-arm fast:                   1
# 4603     NZ:Right-hand bat:Left-arm fast-medium:                   0
# 7783     NZ:Left-hand bat:Right-arm medium-fast:                   0
# 12607   SA:Right-hand bat:Right-arm medium-fast:                   0
# 20730  ENG:Right-hand bat:Right-arm fast-medium:                   0
# 23028  ENG:Left-hand bat:Slow left-arm orthodox:                   0
# 23178                SL:Right-hand bat:Legbreak:                   0
#
#        is_batsman_keeper  inning  runs  balls_faced  ...  bowler_id  \
# 1468                   0       1     0            0  ...  2214554.0
# 4603                   0       1     0            0  ...  2649485.0
# 7783                   0       2     0            0  ...  5490638.0
# 12607                  0       1     0            0  ...  4165265.0
# 20730                  0       1     0            0  ...  4433547.0
# 23028                  0       2     0            0  ...  2018001.0
# 23178                  0       2     0            0  ...        NaN
#
#        bowler_dob                              bowler_details  \
# 1468   1987-07-15   PAK:Right-hand bat:Right-arm medium-fast:
# 4603   1989-02-13      IND:Right-hand bat:Right-arm offbreak:
# 7783   1997-02-13            SL:Left-hand bat:Right-arm fast:
# 12607  1997-05-25           SA:Right-hand bat:Right-arm fast:
# 20730  1995-01-10  AFG:Right-hand bat:Slow left-arm orthodox:
# 23028  1991-01-08    AUS:Left-hand bat:Right-arm fast-medium:
# 23178         NaN                                         NaN
#
#       is_bowler_keeper  is_bowler_captain strike_rate Fours  Sixes  \
# 1468               0.0                0.0         NaN     0      0
# 4603               0.0                0.0         NaN     0      0
# 7783               0.0                0.0         NaN     0      0
# 12607              0.0                0.0         NaN     0      0
# 20730              0.0                0.0         NaN     0      0
# 23028              0.0                0.0         NaN     0      0
# 23178              NaN                NaN         NaN     0      0
#
#          match_dt     ingestion_timestamp
# 1468   2021-06-13 2022-03-22 12:43:21.000
# 4603   2023-04-30 2024-03-26 03:41:36.000
# 7783   2023-04-08 2024-03-26 03:41:36.000
# 12607  2022-11-02 2023-03-10 21:21:02.995
# 20730  2022-05-27 2023-03-10 21:21:02.995
# 23028  2022-06-03 2023-03-10 21:21:02.995
# 23178  2022-12-23 2023-03-10 21:21:02.995
#
# [7 rows x 24 columns]

# %%
mask_balls_faced_0 = (batsman_df['balls_faced'] == 0) & (batsman_df['strike_rate'].isna())

# Set strike_rate to 0 where balls_faced is 0 and strike_rate is NaN
batsman_df.loc[mask_balls_faced_0, 'strike_rate'] = 0

# %%
batsman_df.isnull().sum()
# Out:
# match id                  0
# batsman                   0
# batsman_id                0
# batsman_dob               0
# batsman_details           0
# is_batsman_captain        0
# is_batsman_keeper         0
# inning                    0
# runs                      0
# balls_faced               0
# over_faced_first          0
# wicket kind            1245
# out_by_bowler          1245
# out_by_fielder            0
# bowler_id              1790
# bowler_dob             1790
# bowler_details         1790
# is_bowler_keeper       1473
# is_bowler_captain      1790
# strike_rate               0
# Fours                     0
# Sixes                     0
# match_dt                  0
# ingestion_timestamp       0
# dtype: int64

# %%
batsman_df['wicket kind'].fillna('Unknown', inplace=True)

# %%
batsman_df['out_by_bowler'] = batsman_df['out_by_bowler'].fillna('Unknown')

# %%
batsman_df.isnull().sum()
# Out:
# match id                  0
# batsman                   0
# batsman_id                0
# batsman_dob               0
# batsman_details           0
# is_batsman_captain        0
# is_batsman_keeper         0
# inning                    0
# runs                      0
# balls_faced               0
# over_faced_first          0
# wicket kind               0
# out_by_bowler             0
# out_by_fielder            0
# bowler_id              1790
# bowler_dob             1790
# bowler_details         1790
# is_bowler_keeper       1473
# is_bowler_captain      1790
# strike_rate               0
# Fours                     0
# Sixes                     0
# match_dt                  0
# ingestion_timestamp       0
# dtype: int64

# %%
column_names = batsman_df.columns

# Get the data types of all columns
column_dtypes = batsman_df.dtypes

# Combine column names and data types into a DataFrame
column_info = pd.DataFrame({'Data Type': column_dtypes})

print(column_info)
# Out:
#                           Data Type
# match id                      int64
# batsman                      object
# batsman_id                    int64
# batsman_dob                  object
# batsman_details              object
# is_batsman_captain            int64
# is_batsman_keeper             int64
# inning                        int64
# runs                          Int64
# balls_faced                   int64
# over_faced_first            float64
# wicket kind                  object
# out_by_bowler                object
# out_by_fielder               object
# bowler_id                   float64
# bowler_dob                   object
# bowler_details               object
# is_bowler_keeper            float64
# is_bowler_captain           float64
# strike_rate                 float64
# Fours                        object
# Sixes                        object
# match_dt                     object
# ingestion_timestamp  datetime64[ns]

# %%
numerical_cols = batsman_df.select_dtypes(include=['int64', 'float64']).columns

# %%
numerical_cols
# Out:
# Index(['match id', 'batsman_id', 'is_batsman_captain', 'is_batsman_keeper',
#        'inning', 'runs', 'balls_faced', 'over_faced_first', 'bowler_id',
#        'is_bowler_keeper', 'is_bowler_captain', 'strike_rate'],
#       dtype='object')

# %%
# Columns to remove
cols_to_remove = ['match id', 'batsman_id', 'is_batsman_captain', 'is_batsman_keeper', 'inning', 'is_bowler_keeper', 'is_bowler_captain', 'bowler_id']

numerical_cols = list(numerical_cols)

# Remove columns from the list
for col in cols_to_remove:
    if col in numerical_cols:
        numerical_cols.remove(col)

# %%
numerical_cols
# Out:
# ['runs', 'balls_faced', 'over_faced_first', 'strike_rate']

# %%
for col in numerical_cols:
    Q1 = batsman_df[col].quantile(0.25)
    Q3 = batsman_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = batsman_df[(batsman_df[col] < lower_bound) | (batsman_df[col] > upper_bound)][col]
    print(f"Outliers in column '{col}': {outliers.values}")
# Out:
# Outliers in column 'runs': <IntegerArray>
# [ 69,  79,  68,  75,  65,  76,  73,  87,  82,  75,
#  ...
#   96,  75,  68,  69,  67,  69,  85,  82,  65, 139]
# Length: 1095, dtype: Int64
# Outliers in column 'balls_faced': [55 52 49 53 48 54 48 48 53 57 46 50 52 52 46 59 46 50 45 60 51 61 46 57
#  48 54 49 47 47 50 59 53 56 66 47 59 47 50 52 47 45 54 48 53 59 46 48 45
#  48 51 60 55 59 60 54 55 54 57 64 50 58 56 47 48 49 63 57 47 46 57 49 55
#  47 62 58 55 67 45 48 45 65 45 46 57 54 52 53 48 47 48 52 45 64 56 47 61
#  53 67 50 51 45 47 46 50 51 60 58 50 54 47 49 50 50 57 63 61 51 46 59 49
#  55 63 51 58 60 62 48 57 50 46 56 47 54 50 49 57 55 48 55 45 51 47 53 51
#  62 60 51 49 47 47 58 67 52 52 50 47 47 58 52 47 46 61 45 62 45 51 53 45
#  58 56 51 62 47 50 48 47 46 47 53 51 50 45 47 45 45 46 67 52 53 51 51 64
#  55 48 63 48 50 47 45 53 62 52 49 64]
# Outliers in column 'over_faced_first': [-18.3 -18.3 -18.3 -18.2]
# Outliers in column 'strike_rate': [300.         280.         280.         600.         400.
#  600.         340.         400.         333.33       300.
#  400.         283.33       350.         375.         500.
#  500.         400.         288.88888889 600.         320.
#  300.         288.89       333.33       350.         400.
#  287.5        366.67       300.         500.         400.
#  400.         600.         500.         600.         500.
#  320.         344.44       350.         350.         300.
#  400.         300.         325.         356.25       300.
#  300.         350.         345.45       309.09       440.
#  300.         400.         300.         300.         600.
#  285.71       300.         344.44       333.33       300.
#  300.         322.22       300.         533.33       314.29
#  300.         350.         320.         300.         350.
#  357.14       600.         278.26       287.5        400.
#  350.         300.         400.         366.67       300.
#  295.         300.         350.         400.         328.57
#  285.71       325.         333.33       300.         300.
#  283.33       400.         400.         300.         287.5
#  307.14       280.         400.         380.         289.47
#  400.         400.         300.         300.         280.
#  300.         300.         300.         350.         333.33
#  281.25       300.         600.         300.         283.33
#  300.         416.67       300.         500.         278.57
#  400.         300.         314.29       300.         325.
#  350.         600.         300.         300.         400.
#  366.67       300.         357.14       340.         400.
#  300.         433.33       400.         600.         400.
#  283.33       283.33       280.         400.         300.
#  316.67       290.         300.         300.         300.
#  400.         600.         400.         400.         333.33
#  300.         333.33       400.         400.         400.
#  300.         292.31       280.         400.         300.
#  400.         373.33333333 400.         280.         307.14
#  357.14       300.         315.38       433.33       500.
#  350.         285.71       300.         600.         300.
#  350.         300.         400.         306.25       350.
#  325.         400.         350.         333.33       311.11
#  300.         300.         400.         400.         400.
#  300.         322.22       333.33       400.         400.
#  300.         300.         280.         600.         333.33
#  350.         600.         316.67       300.         336.36
#  400.         320.         338.46       320.         300.
#  350.         300.         300.         285.71       300.
#  400.         300.         400.         300.         333.33
#  400.         400.         340.         300.         300.
#  307.69       316.67       400.         400.         333.33
#  285.71       366.67       466.67       300.         400.
#  350.         283.33       400.         400.         320.
#  371.43       290.         300.         292.31       285.71
#  281.25       300.         400.         300.         350.
#  300.         466.67       340.         300.         450.
#  300.         385.71       285.71       300.         300.
#  371.43       400.         357.14       300.         344.44
#  400.         330.77       283.33       350.         350.
#  300.         277.78       400.         300.         300.
#  285.71       300.         280.         333.33       300.
#  300.         350.         346.15       300.         400.
#  300.         400.         300.         425.         281.82
#  316.67       310.         300.         333.33       366.67
#  400.         321.05       312.5        400.         357.14
#  333.33       295.83       350.         600.         279.17
#  400.         300.         400.         300.         333.33
#  400.         350.         333.33       281.82       300.
#  321.43       291.67       300.         460.         344.44
#  328.57       333.33       300.         300.         300.
#  300.         300.         362.5        300.         283.33
#  350.         350.         400.         280.         300.
#  400.         350.         350.         300.         354.55
#  281.82       333.33       400.         400.         300.
#  300.         600.         277.78       500.         284.21
#  293.33       600.         333.33       333.33       285.71
#  280.         314.29       350.         400.         300.
#  400.         600.         300.         400.         300.
#  300.         300.         400.         400.         283.33
#  600.         350.         289.47       300.         300.
#  333.33       350.         400.         400.         283.33
#  400.         300.         600.         300.         500.
#  400.         600.         333.33       350.         355.56
#  466.67       333.33       318.18       300.         350.
#  400.         300.         300.         400.         300.        ]

# %%
for col in numerical_cols:
    Q1 = batsman_df[col].quantile(0.25)
    Q3 = batsman_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    non_outliers = batsman_df[(batsman_df[col] >= lower_bound) & (batsman_df[col] <= upper_bound)][col]
    mean_value = int(np.round(non_outliers.mean()))  # Round off the mean value
    batsman_df.loc[batsman_df[col] < lower_bound, col] = mean_value
    batsman_df.loc[batsman_df[col] > upper_bound, col] = mean_value

# %%
column_names = batsman_df.columns

# Get the data types of all columns
column_dtypes = batsman_df.dtypes

# Combine column names and data types into a DataFrame
column_info = pd.DataFrame({'Data Type': column_dtypes})

print(column_info)
# Out:
#                           Data Type
# match id                      int64
# batsman                      object
# batsman_id                    int64
# batsman_dob                  object
# batsman_details              object
# is_batsman_captain            int64
# is_batsman_keeper             int64
# inning                        int64
# runs                          Int64
# balls_faced                   int64
# over_faced_first            float64
# wicket kind                  object
# out_by_bowler                object
# out_by_fielder               object
# bowler_id                   float64
# bowler_dob                   object
# bowler_details               object
# is_bowler_keeper            float64
# is_bowler_captain           float64
# strike_rate                 float64
# Fours                        object
# Sixes                        object
# match_dt                     object
# ingestion_timestamp  datetime64[ns]

# %%
# Convert columns to the appropriate datatypes
batsman_df['match id'] = batsman_df['match id'].astype(int)
batsman_df['batsman'] = batsman_df['batsman'].astype('string')
batsman_df['batsman_id'] = batsman_df['batsman_id'].astype(int)
batsman_df['batsman_details'] = batsman_df['batsman_details'].astype('string')
batsman_df['inning'] = batsman_df['inning'].astype(int)
batsman_df['runs'] = batsman_df['runs'].astype('Int64')
batsman_df['balls_faced'] = batsman_df['balls_faced'].astype(int)
batsman_df['over_faced_first'] = batsman_df['over_faced_first'].astype(float)
batsman_df['wicket kind'] = batsman_df['wicket kind'].astype('string')
batsman_df['out_by_bowler'] = batsman_df['out_by_bowler'].astype('string')
batsman_df['out_by_fielder'] = batsman_df['out_by_fielder'].astype('string')
batsman_df['bowler_id'] = pd.to_numeric(batsman_df['bowler_id'], errors='coerce').astype('Int64')  # allows for NULL values
batsman_df['bowler_details'] = batsman_df['bowler_details'].astype('string')
batsman_df['is_bowler_keeper'] = batsman_df['is_bowler_keeper'].astype('Int64').astype(bool, errors='ignore')  # allows for blank values
batsman_df['strike_rate'] = batsman_df['strike_rate'].astype(float)

# Convert Fours and Sixes columns to integers, handling non-integer float values
batsman_df['Fours'] = pd.to_numeric(batsman_df['Fours'], errors='coerce').fillna(0).astype(int).astype('Int64')  # handles NULL and non-integer float values
batsman_df['Sixes'] = pd.to_numeric(batsman_df['Sixes'], errors='coerce').fillna(0).astype(int).astype('Int64')  # handles NULL and non-integer float values

# %%
# Function to parse dates
def parse_dates(date_str):
    for fmt in ('%Y-%m-%d %H:%M:%S', '%Y-%m-%d'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            pass
    return pd.NaT

# Apply the date parsing function
batsman_df['batsman_dob'] = batsman_df['batsman_dob'].apply(parse_dates)
batsman_df['bowler_dob'] = batsman_df['bowler_dob'].apply(parse_dates)
batsman_df['match_dt'] = batsman_df['match_dt'].apply(parse_dates)

# Format the dates to MM/DD/YYYY
batsman_df['batsman_dob'] = batsman_df['batsman_dob'].dt.strftime('%m/%d/%Y')
batsman_df['bowler_dob'] = batsman_df['bowler_dob'].dt.strftime('%m/%d/%Y')
batsman_df['match_dt'] = batsman_df['match_dt'].dt.strftime('%m/%d/%Y')

print(batsman_df[['batsman_dob', 'bowler_dob','match_dt']])
# Out:
#       batsman_dob  bowler_dob    match_dt
# 56     11/21/1984  08/01/2000  01/25/2021
# 57     11/21/1984  09/22/1994  01/18/2021
# 58     11/21/1984  03/29/1990  01/24/2021
# 59     11/21/1984  03/28/2001  01/04/2021
# 60     11/21/1984  12/18/1988  01/01/2021
# ...           ...         ...         ...
# 24920  12/23/2003         NaN  11/04/2023
# 24921  11/24/2005  11/10/1996  10/21/2023
# 24922  05/06/2002  09/17/1990  12/19/2023
# 24923  06/04/2005         NaN  12/29/2023
# 24924  02/22/1997  09/22/2000  12/29/2023
#
# [24869 rows x 3 columns]

# %%
column_names = batsman_df.columns

# Get the data types of all columns
column_dtypes = batsman_df.dtypes

# Combine column names and data types into a DataFrame
column_info = pd.DataFrame({'Data Type': column_dtypes})

print(column_info)
# Out:
#                           Data Type
# match id                      int32
# batsman                      string
# batsman_id                    int32
# batsman_dob                  object
# batsman_details              string
# is_batsman_captain            int64
# is_batsman_keeper             int64
# inning                        int32
# runs                          Int64
# balls_faced                   int32
# over_faced_first            float64
# wicket kind                  string
# out_by_bowler                string
# out_by_fielder               string
# bowler_id                     Int64
# bowler_dob                   object
# bowler_details               string
# is_bowler_keeper              Int64
# is_bowler_captain           float64
# strike_rate                 float64
# Fours                         Int64
# Sixes                         Int64
# match_dt                     object
# ingestion_timestamp  datetime64[ns]

# %%
final_output = 'batsman.xlsx'
batsman_df.to_excel(final_output, index=False)

# %%
all_columns = batsman_df.columns

# Print the column names
print(all_columns)
# Out:
# Index(['match id', 'batsman', 'batsman_id', 'batsman_dob', 'batsman_details',
#        'is_batsman_captain', 'is_batsman_keeper', 'inning', 'runs',
#        'balls_faced', 'over_faced_first', 'wicket kind', 'out_by_bowler',
#        'out_by_fielder', 'bowler_id', 'bowler_dob', 'bowler_details',
#        'is_bowler_keeper', 'is_bowler_captain', 'strike_rate', 'Fours',
#        'Sixes', 'match_dt', 'ingestion_timestamp'],
#       dtype='object')
